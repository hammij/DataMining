# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv0 = pd.read_csv("0.csv", header=None)
csv1 = pd.read_csv("1.csv", header=None)
csv2 = pd.read_csv("2.csv", header=None)
csv3 = pd.read_csv("3.csv", header=None)

# %% [markdown]
# Making copies..

# %%
cs0=csv0.copy(deep=True)
cs1=csv1.copy(deep=True)
cs2=csv2.copy(deep=True)
cs3=csv3.copy(deep=True)

# %% [markdown]
# Naming columns..

# %%
num_cols = len(list(csv0)) # get length of columns

rng = range(1, (num_cols + 1))

cs0.columns = ['x' + str(i) for i in rng]
cs1.columns = ['x' + str(i) for i in rng]
cs2.columns = ['x' + str(i) for i in rng]
cs3.columns = ['x' + str(i) for i in rng]

# %% [markdown]
# Separating sensor and action wise data..

# %%
s1=range(1, 58, 8)
s2=range(2, 59, 8)
s3=range(3, 60, 8)
s4=range(4, 61, 8)
s5=range(5, 62, 8)
s6=range(6, 63, 8)
s7=range(7, 64, 8)
s8=range(8, 65, 8)
sensor01 = cs0.loc[:,['x'+str(i) for i in s1]] #action 0 & sensor 1
sensor02 = cs0.loc[:,['x'+str(i) for i in s2]] #action 0 & sensor 2
sensor03 = cs0.loc[:,['x'+str(i) for i in s3]]
sensor04 = cs0.loc[:,['x'+str(i) for i in s4]]
sensor05 = cs0.loc[:,['x'+str(i) for i in s5]]
sensor06 = cs0.loc[:,['x'+str(i) for i in s6]]
sensor07 = cs0.loc[:,['x'+str(i) for i in s7]]
sensor08 = cs0.loc[:,['x'+str(i) for i in s8]] #action 0 & sensor 8

sensor11 = cs1.loc[:,['x'+str(i) for i in s1]] #action 1 and sensor 1
sensor12 = cs1.loc[:,['x'+str(i) for i in s2]]
sensor13 = cs1.loc[:,['x'+str(i) for i in s3]]
sensor14 = cs1.loc[:,['x'+str(i) for i in s4]]
sensor15 = cs1.loc[:,['x'+str(i) for i in s5]]
sensor16 = cs1.loc[:,['x'+str(i) for i in s6]]
sensor17 = cs1.loc[:,['x'+str(i) for i in s7]]
sensor18 = cs1.loc[:,['x'+str(i) for i in s8]]

sensor21 = cs2.loc[:,['x'+str(i) for i in s1]] #action 2 and sensor 1
sensor22 = cs2.loc[:,['x'+str(i) for i in s2]]
sensor23 = cs2.loc[:,['x'+str(i) for i in s3]]
sensor24 = cs2.loc[:,['x'+str(i) for i in s4]]
sensor25 = cs2.loc[:,['x'+str(i) for i in s5]]
sensor26 = cs2.loc[:,['x'+str(i) for i in s6]]
sensor27 = cs2.loc[:,['x'+str(i) for i in s7]]
sensor28 = cs2.loc[:,['x'+str(i) for i in s8]]

sensor31 = cs3.loc[:,['x'+str(i) for i in s1]]
sensor32 = cs3.loc[:,['x'+str(i) for i in s2]]
sensor33 = cs3.loc[:,['x'+str(i) for i in s3]]
sensor34 = cs3.loc[:,['x'+str(i) for i in s4]]
sensor35 = cs3.loc[:,['x'+str(i) for i in s5]]
sensor36 = cs3.loc[:,['x'+str(i) for i in s6]]
sensor37 = cs3.loc[:,['x'+str(i) for i in s7]]
sensor38 = cs3.loc[:,['x'+str(i) for i in s8]]

# %%
#For sensor 1
list01=sensor01.values.tolist()   #Convert dataframe to list of lists - action 0, sensor 1
flist01 = [item for sublist in list01 for item in sublist] #Converting list of lists to flattened list

list11=sensor11.values.tolist() #action 1, sensor 1
flist11 = [item for sublist in list11 for item in sublist]

list21=sensor21.values.tolist() #action 2, sensor 1
flist21 = [item for sublist in list21 for item in sublist]

list31=sensor31.values.tolist() #action 3, sensor 1
flist31 = [item for sublist in list31 for item in sublist]

#For sensor 2
list02=sensor02.values.tolist()   #Convert dataframe to list of lists - action 0, sensor 2
flist02 = [item for sublist in list02 for item in sublist] #Converting list of lists to flattened list

list12=sensor12.values.tolist()
flist12 = [item for sublist in list12 for item in sublist]

list22=sensor22.values.tolist()
flist22 = [item for sublist in list22 for item in sublist]

list32=sensor32.values.tolist()
flist32 = [item for sublist in list32 for item in sublist]

#For sensor 3
list03=sensor03.values.tolist()   #Convert dataframe to list of lists - action 0, sensor 3
flist03 = [item for sublist in list03 for item in sublist] #Converting list of lists to flattened list

list13=sensor13.values.tolist()
flist13 = [item for sublist in list13 for item in sublist]

list23=sensor23.values.tolist()
flist23 = [item for sublist in list23 for item in sublist]

list33=sensor33.values.tolist()
flist33 = [item for sublist in list33 for item in sublist]

#For sensor 4
list04=sensor04.values.tolist()   #Convert dataframe to list of lists - action 0, sensor 4
flist04 = [item for sublist in list04 for item in sublist] #Converting list of lists to flattened list

list14=sensor14.values.tolist()
flist14 = [item for sublist in list14 for item in sublist]

list24=sensor24.values.tolist()
flist24 = [item for sublist in list24 for item in sublist]

list34=sensor34.values.tolist()
flist34 = [item for sublist in list34 for item in sublist]

#For sensor 5
list05=sensor05.values.tolist()   #Convert dataframe to list of lists - action 0, sensor 5
flist05 = [item for sublist in list05 for item in sublist] #Converting list of lists to flattened list

list15=sensor15.values.tolist()
flist15 = [item for sublist in list15 for item in sublist]

list25=sensor25.values.tolist()
flist25 = [item for sublist in list25 for item in sublist]

list35=sensor35.values.tolist()
flist35 = [item for sublist in list35 for item in sublist]

#For sensor 6
list06=sensor06.values.tolist()   #Convert dataframe to list of lists - action 0, sensor 6
flist06 = [item for sublist in list06 for item in sublist] #Converting list of lists to flattened list

list16=sensor16.values.tolist()
flist16 = [item for sublist in list16 for item in sublist]

list26=sensor26.values.tolist()
flist26 = [item for sublist in list26 for item in sublist]

list36=sensor36.values.tolist()
flist36 = [item for sublist in list36 for item in sublist]

#For sensor 7
list07=sensor07.values.tolist()   #Convert dataframe to list of lists - action 0, sensor 7
flist07 = [item for sublist in list07 for item in sublist] #Converting list of lists to flattened list

list17=sensor17.values.tolist()
flist17 = [item for sublist in list17 for item in sublist]

list27=sensor27.values.tolist()
flist27 = [item for sublist in list27 for item in sublist]

list37=sensor37.values.tolist()
flist37 = [item for sublist in list37 for item in sublist]

#For sensor 8
list08=sensor08.values.tolist()   #Convert dataframe to list of lists - action 0, sensor 8
flist08 = [item for sublist in list08 for item in sublist] #Converting list of lists to flattened list

list18=sensor18.values.tolist()
flist18 = [item for sublist in list18 for item in sublist]

list28=sensor28.values.tolist()
flist28 = [item for sublist in list28 for item in sublist]

list38=sensor38.values.tolist()
flist38 = [item for sublist in list38 for item in sublist]

# %% [markdown]
# ### Action 0 (Rock)

# %%
index=range(1,23281) #For x axis

plt.suptitle('Sensor wise graphs for action rock',fontsize=14)

plt.plot(index,flist01,label='Signals')
plt.plot(flist01.index(max(flist01)), max(flist01), 'ro', label='max: ' + str(max(flist01)))
plt.plot(flist01.index(min(flist01)), min(flist01), 'go', label='min: ' + str(min(flist01)))
plt.title('Sensor1')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist02,label='Signals')
plt.plot(flist02.index(max(flist02)), max(flist02), 'ro', label='max: ' + str(max(flist02)))
plt.plot(flist02.index(min(flist02)), min(flist02), 'go', label='min: ' + str(min(flist02)))
plt.title('Sensor2')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist03,label='Signals')
plt.plot(flist03.index(max(flist03)), max(flist03), 'ro', label='max: ' + str(max(flist03)))
plt.plot(flist03.index(min(flist03)), min(flist03), 'go', label='min: ' + str(min(flist03)))
plt.title('Sensor3')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist04,label='Signals')
plt.plot(flist04.index(max(flist04)), max(flist04), 'ro', label='max: ' + str(max(flist04)))
plt.plot(flist04.index(min(flist04)), min(flist04), 'go', label='min: ' + str(min(flist04)))
plt.title('Sensor4')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist05,label='Signals')
plt.plot(flist05.index(max(flist05)), max(flist05), 'ro', label='max: ' + str(max(flist05)))
plt.plot(flist05.index(min(flist05)), min(flist05), 'go', label='min: ' + str(min(flist05)))
plt.title('Sensor5')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist06,label='Signals')
plt.plot(flist06.index(max(flist06)), max(flist06), 'ro', label='max: ' + str(max(flist06)))
plt.plot(flist06.index(min(flist06)), min(flist06), 'go', label='min: ' + str(min(flist06)))
plt.title('Sensor6')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist07,label='Signals')
plt.plot(flist07.index(max(flist07)), max(flist07), 'ro', label='max: ' + str(max(flist07)))
plt.plot(flist07.index(min(flist07)), min(flist07), 'go', label='min: ' + str(min(flist07)))
plt.title('Sensor7')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist08,label='Signals')
plt.plot(flist08.index(max(flist08)), max(flist08), 'ro', label='max: ' + str(max(flist08)))
plt.plot(flist08.index(min(flist08)), min(flist08), 'go', label='min: ' + str(min(flist08)))
plt.title('Sensor8')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Action 2 (Paper)

# %%
index=range(1,23545) #For x axis

plt.suptitle('Sensor wise graphs for action paper',fontsize=14)

plt.plot(index,flist21,label='Signals')
plt.plot(flist21.index(max(flist21)), max(flist21), 'ro', label='max: ' + str(max(flist21)))
plt.plot(flist21.index(min(flist21)), min(flist21), 'go', label='min: ' + str(min(flist21)))
plt.title('Sensor1')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist22,label='Signals')
plt.plot(flist22.index(max(flist22)), max(flist22), 'ro', label='max: ' + str(max(flist22)))
plt.plot(flist22.index(min(flist22)), min(flist22), 'go', label='min: ' + str(min(flist22)))
plt.title('Sensor2')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist23,label='Signals')
plt.plot(flist23.index(max(flist23)), max(flist23), 'ro', label='max: ' + str(max(flist23)))
plt.plot(flist23.index(min(flist23)), min(flist23), 'go', label='min: ' + str(min(flist23)))
plt.title('Sensor3')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist24,label='Signals')
plt.plot(flist24.index(max(flist24)), max(flist24), 'ro', label='max: ' + str(max(flist24)))
plt.plot(flist24.index(min(flist24)), min(flist24), 'go', label='min: ' + str(min(flist24)))
plt.title('Sensor4')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist25,label='Signals')
plt.plot(flist25.index(max(flist25)), max(flist25), 'ro', label='max: ' + str(max(flist25)))
plt.plot(flist25.index(min(flist25)), min(flist25), 'go', label='min: ' + str(min(flist25)))
plt.title('Sensor5')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist26,label='Signals')
plt.plot(flist26.index(max(flist26)), max(flist26), 'ro', label='max: ' + str(max(flist26)))
plt.plot(flist26.index(min(flist26)), min(flist26), 'go', label='min: ' + str(min(flist26)))
plt.title('Sensor6')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist27,label='Signals')
plt.plot(flist27.index(max(flist27)), max(flist27), 'ro', label='max: ' + str(max(flist27)))
plt.plot(flist27.index(min(flist27)), min(flist27), 'go', label='min: ' + str(min(flist27)))
plt.title('Sensor7')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

plt.plot(index,flist28,label='Signals')
plt.plot(flist28.index(max(flist28)), max(flist28), 'ro', label='max: ' + str(max(flist28)))
plt.plot(flist28.index(min(flist28)), min(flist28), 'go', label='min: ' + str(min(flist28)))
plt.title('Sensor8')
plt.xlabel("Index")
plt.ylabel("Sensor Signals")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# Comparing max and min of each sensor in action rock and acion paper

# %%
ys01=[max(flist01),max(flist02),max(flist03),max(flist04),max(flist05),max(flist06),max(flist07),max(flist08)]
ys02=[min(flist01),min(flist02),min(flist03),min(flist04),min(flist05),min(flist06),min(flist07),min(flist08)]
ys21=[max(flist21),max(flist22),max(flist23),max(flist24),max(flist25),max(flist26),max(flist27),max(flist28)]
ys22=[min(flist21),min(flist22),min(flist23),min(flist24),min(flist25),min(flist26),min(flist27),min(flist28)]
xs=range(1,9)

plt.plot(xs,ys01,label='max action rock')
plt.plot(xs,ys02,label='min action rock')
plt.plot(xs,ys21,label='max action paper')
plt.plot(xs,ys22,label='min action paper')
plt.title('Max and min of each sensor during action rock and action paper')
plt.xlabel("Sensor#")
plt.ylabel("Sensor Signals")
plt.legend(loc="best")
plt.show()
